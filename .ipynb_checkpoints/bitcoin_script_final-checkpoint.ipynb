# %%
# Text and plotting libraries
import pandas as pd
import re
import os
import codecs
import numpy as np
import seaborn as sns
import string 
import nltk
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from nltk.corpus import stopwords
stop = stopwords.words('english')

import matplotlib.pyplot as plt
% matplotlib inline

os.chdir("C://Users//yingquli//Desktop//Bitcoin_Data2")

# %%
# Importing sklearn libraries; Feature Engineering and Scaling
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import (RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor)
from sklearn.feature_selection import RFE
from sklearn.linear_model import (LinearRegression, Lasso, Ridge)

# Importing sklearn libraries; Modeling
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
# Working files:
# train_timeseries2.csv

# Reading in the working file
time = pd.read_csv("train_timeseries2.csv", index_col = "date")

# %%
# Moving the 'close' variable to the end of the file
time = time[[c for c in time if c not in ['close']] + ['close']]

# Droping the date column; perhaps we need it later
#time.drop('date', axis=1, inplace=True)

# Displaying a cut of the data and the dimensions of the data
display(time.head())
display(time.shape)

# Splitting data into the independent and dependent variables
X = time.iloc[:, 0:45]
y = time.iloc[:, -1]
# Out:
#             avg_block_size  blocks_size  cost_per_transaction_percent  \
# date
# 2016-04-24        0.728040  66022.67805                      1.385967
# 2016-04-25        0.874485  66133.73765                      0.888460
# 2016-04-26        0.813180  66256.52779                      1.129962
# 2016-04-27        0.875343  66369.44708                      0.873767
# 2016-04-28        0.898219  66491.60486                      0.904082
#
#             cost_per_transaction    difficulty  est_transaction_volume_USD  \
# date
# 2016-04-24              8.360698  1.786780e+11                 110486293.2
# 2016-04-25              6.861613  1.786780e+11                 168025613.1
# 2016-04-26              7.675906  1.786780e+11                 170332016.5
# 2016-04-27              6.111057  1.786780e+11                 167458968.2
# 2016-04-28              6.261128  1.786660e+11                 171720826.0
#
#             est_transaction_volume    hash_rate  median_confirmation_time  \
# date
# 2016-04-24             240501.2912  1172443.384                  8.783333
# 2016-04-25             362233.4608  1128032.650                  9.683333
# 2016-04-26             363972.8546  1341204.175                  7.750000
# 2016-04-27             374368.9346  1145796.944                 10.366667
# 2016-04-28             381601.8356  1207843.183                 10.000000
#
#             miners_revenue   ...    transactions_per_sec_max  utxo_count_mean  \
# date                         ...
# 2016-04-24     1531303.620   ...                    4.266667      36783070.63
# 2016-04-25     1492839.928   ...                    8.016667      36870963.17
# 2016-04-26     1924687.353   ...                    9.500000      36931936.13
# 2016-04-27     1463200.885   ...                   13.300000      37022472.54
# 2016-04-28     1552496.677   ...                   11.250000      37077491.25
#
#             utxo_count_stddev  utxo_count_min  utxo_count_max  \
# date
# 2016-04-24        27228.75866        36724621        36825214
# 2016-04-25        17998.12914        36825828        36893715
# 2016-04-26        16768.83707        36895435        36980350
# 2016-04-27        16423.15703        36983148        37044068
# 2016-04-28        18568.44670        37046272        37106607
#
#             news_stories_total  news_stories_positive  news_stories_negative  \
# date
# 2016-04-24                   6                      2                      0
# 2016-04-25                  25                      7                      8
# 2016-04-26                  32                     14                     14
# 2016-04-27                  18                      8                      4
# 2016-04-28                  24                     12                      7
#
#             news_stories_neutral   close
# date
# 2016-04-24                     4  458.55
# 2016-04-25                    10  461.43
# 2016-04-26                     4  466.09
# 2016-04-27                     6  444.69
# 2016-04-28                     5  449.01
#
# [5 rows x 46 columns]
# (951, 46)

# %%
# Need to work on the labling
plt.figure(figsize = (15, 15))
sns.heatmap(time.corr(), cmap="Blues", xticklabels=True, yticklabels=True)

# %%
# Min-Max Scaling of all the input features
scaler = MinMaxScaler()
timeScaled = scaler.fit_transform(time)
time.loc[:, time.columns != "close"] = scaler.fit_transform(time.loc[:, time.columns != "close"])

# %%
# Recursive feature elimination with Linear Regression
lr = LinearRegression()
featureSelector = RFE(lr, n_features_to_select = 20, verbose = 3)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultLR = features[featuresBoolean]

# Recursive feature elimination with Lasso Regression
lasso = Lasso()
featureSelector = RFE(lasso, n_features_to_select = 20)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultLasso = features[featuresBoolean]

# Recursive feature elimination with Ridge Regression
ridge = Ridge()
featureSelector = RFE(ridge, n_features_to_select = 20)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultRidge = features[featuresBoolean]

# Recursive feature elimination with Random Forest
rf = RandomForestRegressor(n_estimators = 200)
featureSelector = RFE(rf, n_features_to_select = 20)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultRF = features[featuresBoolean]

# Recursive feature elimination with AdaBoost
ab = AdaBoostRegressor(n_estimators = 200)
featureSelector = RFE(ab, n_features_to_select = 20)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultAB = features[featuresBoolean]

# Recursive feature elimination with Gradient Boosting 
gb = GradientBoostingRegressor(n_estimators = 200, learning_rate = 0.05)
featureSelector = RFE(gb, n_features_to_select = 20)

featureSelector.fit(X.values, y.values)

featuresBoolean = np.array(featureSelector.support_)
features = np.array(X.columns)
resultGB = features[featuresBoolean]

# %%
importantFeatureDict = {}

for i in range(0, 20):
    # Linear Regression
    if resultLR[i] not in importantFeatureDict:
        importantFeatureDict[resultLR[i]] = 1
    else:
         importantFeatureDict[resultLR[i]] += 1
    
    # Lasso
    if resultLasso[i] not in importantFeatureDict:
        importantFeatureDict[resultLasso[i]] = 1
    else:
         importantFeatureDict[resultLasso[i]] += 1
    
    # Ridge
    if resultRidge[i] not in importantFeatureDict:
        importantFeatureDict[resultRidge[i]] = 1
    else:
         importantFeatureDict[resultRidge[i]] += 1
    
    # Random Forest
    if resultRF[i] not in importantFeatureDict:
        importantFeatureDict[resultRF[i]] = 1
    else:
         importantFeatureDict[resultRF[i]] += 1
       
    # Ada Boost
    if resultAB[i] not in importantFeatureDict:
        importantFeatureDict[resultAB[i]] = 1
    else:
         importantFeatureDict[resultAB[i]] += 1
            
    # Gradient Boosting
    if resultGB[i] not in importantFeatureDict:
        importantFeatureDict[resultGB[i]] = 1
    else:
         importantFeatureDict[resultGB[i]] += 1

# %%
# List of features for modeling after Recursive Feature Elimination
columns = ['cost_per_transaction',
'transaction_fees',
'n_transactions_per_block',
'transactions_per_sec_mean',
'median_confirmation_time',
'news_stories_negative',
'blocks_size',
'est_transaction_volume_USD',
'hash_rate',
'miners_revenue',
'mempool_growth_mean',
'total_bitcoins',
'transactions_per_sec_stddev',
'transactions_per_sec_max',
'news_stories_total',
'news_stories_positive',
'utxo_count_min',
'news_stories_neutral',
'close']

# Extract the important features and display a few rows
timeTrain = time[columns]
display(timeTrain.head())
timeTrain.shape
# Out:
#             cost_per_transaction  transaction_fees  n_transactions_per_block  \
# date
# 2016-04-24              0.028448          0.014055                  0.293042
# 2016-04-25              0.018949          0.020816                  0.465435
# 2016-04-26              0.024109          0.219300                  0.437611
# 2016-04-27              0.014193          0.022712                  0.541148
# 2016-04-28              0.015144          0.025077                  0.530897
#
#             transactions_per_sec_mean  median_confirmation_time  \
# date
# 2016-04-24                   0.147010                  0.130927
# 2016-04-25                   0.224299                  0.169144
# 2016-04-26                   0.290203                  0.087049
# 2016-04-27                   0.277035                  0.198160
# 2016-04-28                   0.297078                  0.182590
#
#             news_stories_negative  blocks_size  est_transaction_volume_USD  \
# date
# 2016-04-24               0.000000     0.000000                    0.006684
# 2016-04-25               0.004343     0.000876                    0.016801
# 2016-04-26               0.007600     0.001845                    0.017206
# 2016-04-27               0.002172     0.002735                    0.016701
# 2016-04-28               0.003800     0.003699                    0.017450
#
#             hash_rate  miners_revenue  mempool_growth_mean  total_bitcoins  \
# date
# 2016-04-24   0.000731        0.012379             0.151748        0.000000
# 2016-04-25   0.000000        0.011644             0.202825        0.001644
# 2016-04-26   0.003510        0.019900             0.227308        0.003599
# 2016-04-27   0.000292        0.011077             0.217285        0.005269
# 2016-04-28   0.001314        0.012785             0.241667        0.007016
#
#             transactions_per_sec_stddev  transactions_per_sec_max  \
# date
# 2016-04-24                     0.059934                  0.005603
# 2016-04-25                     0.134875                  0.102586
# 2016-04-26                     0.250764                  0.140948
# 2016-04-27                     0.286681                  0.239224
# 2016-04-28                     0.200289                  0.186207
#
#             news_stories_total  news_stories_positive  utxo_count_min  \
# date
# 2016-04-24            0.001632               0.001307        0.000000
# 2016-04-25            0.007835               0.004575        0.003276
# 2016-04-26            0.010121               0.009150        0.005529
# 2016-04-27            0.005550               0.005229        0.008369
# 2016-04-28            0.007509               0.007843        0.010412
#
#             news_stories_neutral   close
# date
# 2016-04-24              0.012945  458.55
# 2016-04-25              0.032362  461.43
# 2016-04-26              0.012945  466.09
# 2016-04-27              0.019417  444.69
# 2016-04-28              0.016181  449.01
# (951, 19)

# %%
# Spliting data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(timeTrain.iloc[:, 0:18], 
                                                    timeTrain.iloc[:, 18], 
                                                    test_size = .20, 
                                                    random_state = 0)

# %%
# Training data dimensions
X_train.shape, y_train.shape
# Out:
# ((760, 18), (760,))

# %%
# Testing data dimensions
X_test.shape, y_test.shape
# Out:
# ((191, 18), (191,))

# %%
rf = RandomForestRegressor(n_estimators = 200, max_depth = 6, oob_score = True)
rf.fit(X_train, y_train)

pred = rf.predict(X_train)

print('Coefficient of determination R^2 (training) score: {}'.format(rf.score(X_train, y_train)))
print('Coefficient of determination R^2 (testing) score: {}'.format(rf.score(X_test, y_test)))

print()
print('Out-of-bag score: {}'.format(rf.oob_score_))
# Out:
# Coefficient of determination R^2 (training) score: 0.9965248471761605
# Coefficient of determination R^2 (testing) score: 0.9865809594305506
#
# Out-of-bag score: 0.9897305803441719

# %%
# Comparing the Test dataset values with the predicted values
d = {'Y_test': y_test, 'Predicted': rf.predict(X_test)}
df = pd.DataFrame(data = d)

# %%
df.head(n = 25)
# Out:
#               Y_test     Predicted
# date
# 2018-09-14   6512.71   6533.340768
# 2017-11-13   6559.49   7844.697242
# 2016-12-29    973.50    920.663896
# 2017-03-21   1120.54   1060.886614
# 2017-08-29   4579.02   4434.121404
# 2018-03-17   7916.88   8089.161313
# 2018-07-24   8424.27   7656.307686
# 2018-04-18   8163.42   8318.016903
# 2016-05-08    458.55    452.859916
# 2016-05-25    449.60    455.494172
# 2018-05-22   8041.78   8143.373192
# 2018-03-16   8338.35   8591.320602
# 2018-01-18  11474.90  11746.594241
# 2017-09-05   4376.53   4419.250466
# 2016-12-11    769.73    777.777060
# 2016-11-25    741.65    735.833817
# 2018-01-26  11171.40  10773.942917
# 2016-11-12    705.05    715.790336
# 2018-06-27   6157.13   6357.923218
# 2017-02-16   1027.44   1045.557611
# 2018-09-16   6517.18   6547.547867
# 2017-04-01   1080.50   1048.921397
# 2018-07-06   6673.50   6554.593157
# 2017-05-01   1421.60   1374.512093
# 2016-07-10    649.36    633.048480

# %% [markdown]
# ################################################################################################################################

# %%
# Working files:
# train_tweets.csv
with codecs.open("train_tweets.csv", 'r', encoding='utf-8', errors='ignore') as fdata:
    tweets = pd.read_csv(fdata)
    
tweets.head()
# Out:
#       tweet_id    created_date  \
# 0  7.24098E+17  4/24/2016 4:48
# 1  7.24099E+17  4/24/2016 4:52
# 2    7.241E+17  4/24/2016 4:57
# 3  7.24108E+17  4/24/2016 5:30
# 4  7.24169E+17  4/24/2016 9:30
#
#                                                 text  retweet_count  \
# 0  RT @JohnRLottJr: Hugo Chavez's 35 yr old daugh...          111.0
# 1  RT @zerohedge: US Taxpayer Is Now A Major Coun...           91.0
# 2  RT @TuurDemeester: Ethereum founder has sold 2...           54.0
# 3  This site has the best #Bitcoin Casino games h...            0.0
# 4        Get #Bitcoin loans: https://t.co/fyyZyHGpRr            0.0
#
#   favorite_count  follower_count         account
# 0              0         36499.0   @BitcoinMoney
# 1              0         36499.0   @BitcoinMoney
# 2              0         36499.0   @BitcoinMoney
# 3              1         18633.0  @cryptonewsday
# 4              0         18633.0  @cryptonewsday

# %%
tweets = tweets[tweets['text'].notnull()]

new = tweets["created_date"].str.split(" ", n = 1, expand = True) 
tweets["date"]= new[0] 
tweets["time"]= new[1]

tweets["text"] = tweets["text"].str.replace("@[\w]*|RT @[\w]*:|https://.*", "")
tweets['text'] = tweets['text'].str.replace("[^a-zA-Z#]", " ").str.lower()
tweets['text'] = tweets['text'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))

tweets.head(n=100)
# Out:
#        tweet_id     created_date  \
# 0   7.24098E+17   4/24/2016 4:48
# 1   7.24099E+17   4/24/2016 4:52
# 2     7.241E+17   4/24/2016 4:57
# 3   7.24108E+17   4/24/2016 5:30
# 4   7.24169E+17   4/24/2016 9:30
# 5   7.24184E+17  4/24/2016 10:30
# 6   7.24199E+17  4/24/2016 11:30
# 7   7.24229E+17  4/24/2016 13:30
# 8   7.24253E+17  4/24/2016 15:04
# 9   7.24259E+17  4/24/2016 15:30
# 10  7.24262E+17  4/24/2016 15:40
# 11  7.24262E+17  4/24/2016 15:41
# 12  7.24262E+17  4/24/2016 15:42
# 13  7.24262E+17  4/24/2016 15:42
# 14  7.24263E+17  4/24/2016 15:45
# 15  7.24282E+17  4/24/2016 17:00
# 16  7.24308E+17  4/24/2016 18:42
# 17  7.24309E+17  4/24/2016 18:47
# 18  7.24371E+17  4/24/2016 22:55
# 19  7.24403E+17   4/25/2016 1:00
# 20  7.24407E+17   4/25/2016 1:19
# 21  7.24431E+17   4/25/2016 2:52
# 22  7.24432E+17   4/25/2016 2:55
# 23  7.24432E+17   4/25/2016 2:58
# 24  7.24448E+17   4/25/2016 4:00
# 25  7.24478E+17   4/25/2016 6:00
# 26  7.24493E+17   4/25/2016 7:00
# 27  7.24508E+17   4/25/2016 8:00
# 28  7.24508E+17   4/25/2016 8:00
# 29  7.24512E+17   4/25/2016 8:13
# ..          ...              ...
# 70  7.24737E+17  4/25/2016 23:08
# 71  7.24765E+17   4/26/2016 1:00
# 72  7.24771E+17   4/26/2016 1:23
# 73  7.24795E+17   4/26/2016 3:00
# 74  7.24818E+17   4/26/2016 4:30
# 75   7.2484E+17   4/26/2016 6:00
# 76  7.24871E+17   4/26/2016 8:00
# 77  7.24886E+17   4/26/2016 9:00
# 78  7.24916E+17  4/26/2016 11:00
# 79  7.24946E+17  4/26/2016 13:00
# 80  7.24963E+17  4/26/2016 14:08
# 81  7.24967E+17  4/26/2016 14:21
# 82  7.24989E+17  4/26/2016 15:48
# 83  7.25007E+17  4/26/2016 17:00
# 84  7.25017E+17  4/26/2016 17:42
# 85  7.25023E+17  4/26/2016 18:05
# 86  7.25024E+17  4/26/2016 18:07
# 87  7.25028E+17  4/26/2016 18:26
# 88   7.2503E+17  4/26/2016 18:35
# 89  7.25037E+17  4/26/2016 19:00
# 90  7.25067E+17  4/26/2016 21:00
# 91  7.25073E+17  4/26/2016 21:24
# 92  7.25082E+17  4/26/2016 22:00
# 93  7.25082E+17  4/26/2016 22:01
# 94  7.25085E+17  4/26/2016 22:12
# 95  7.25086E+17  4/26/2016 22:13
# 96  7.25086E+17  4/26/2016 22:16
# 97  7.25097E+17  4/26/2016 23:00
# 98  7.25117E+17   4/27/2016 0:17
# 99  7.25127E+17   4/27/2016 1:00
#
#                                                  text  retweet_count  \
# 0   hugo chavez daughter assets andorran banks doe...          111.0
# 1   taxpayer major counterparty wall street deriva...           91.0
# 2                      ethereum founder sold position           54.0
# 3                this site best #bitcoin casino games            0.0
# 4                                      #bitcoin loans            0.0
# 5                                   discover smartdns            0.0
# 6                              yourself some #bitcoin            0.0
# 7   sell #bitcoins with people your local area cas...            1.0
# 8                            what anyway #readbastiat           20.0
# 9                          this should using #bitcoin            0.0
# 10  there sorry hear your banned please contact su...            0.0
# 11  sure this time seeing more instances than usua...            0.0
# 12                                    reach them here            0.0
# 13  have your wallet mnemonic stored somewhere hav...            1.0
# 14               news vote currencies accept #bitcoin           30.0
# 15  ipvanish stop spies keep your internet browsin...            0.0
# 16  currently investigating reports delayed author...           15.0
# 17  hope currently receiving reports delayed autho...            0.0
# 18  today anniversary #armeniangenocide more reaso...           84.0
# 19  make money trading financial markets without i...            0.0
# 20            latest podcast covers hack details with           16.0
# 21      bitcoin snaps surges fresh highs burst buying          103.0
# 22  #bitcoin very much like highlander with every ...           16.0
# 23                              permissionless market            1.0
# 24  ipvanish private internet browsing logs with #...            0.0
# 25                 learn make money #trading #bitcoin            0.0
# 26     find best cloud mining services rated reviewed            0.0
# 27   smartdns cheapest circumvent internet censorship            0.0
# 28             multisigna most bitcoiny sell #bitcoin            0.0
# 29  morgan stanley report claims private #blockcha...            8.0
# ..                                                ...            ...
# 70  email relay service experiencing outage earlie...            0.0
# 71  using internet black market beginner guide buy...            0.0
# 72  satoshi nakamoto really created future pieter ...           13.0
# 73                            best ways earn #bitcoin            0.0
# 74  clapper snowden disclosures sped adoption stro...           98.0
# 75  access online media available your country che...            0.0
# 76                    #crypto cloud mining comparison            0.0
# 77  possibly fastest shared server hosting with #b...            0.0
# 78  free bets from #bitcoin dice site just claim f...            0.0
# 79  #bitcoin price rise again soon miss boat some ...            0.0
# 80  wall veteran tone vays blockchain companies me...            2.0
# 81  #blockchain #healthcare launches health networ...            9.0
# 82  estonia financial agency stops year long inves...           16.0
# 83  #bitcoin trading with leverage tips deposit bo...            0.0
# 84   excited pedro spread word about #bitcoin tonight            7.0
# 85  today lead strategy explains #fintech growth s...           12.0
# 86  smart contracts described nick szabo years bec...           44.0
# 87                           thanks heads glad seeing            0.0
# 88  networking time meetup about #bitcoin #blockchain           14.0
# 89  what best hosting with #bitcoin check this com...            0.0
# 90  what best #bitcoin poker site check this indep...            0.0
# 91  your request could have been rejected variety ...            1.0
# 92  blazing fast from ipvanish private internet br...            0.0
# 93                                       morning vote           13.0
# 94                        irons awesome show shanghai            1.0
# 95  surprised that cryptsy shapeshift much tractio...            6.0
# 96  people including sameh were killed when drone ...           27.0
# 97          everything need know #bitcoin anonymously            1.0
# 98  bitcoin mining pool bribed regulated censor tr...           33.0
# 99                    bitcoin guides beginners beyond            0.0
#
#    favorite_count  follower_count           account       date   time
# 0               0         36499.0     @BitcoinMoney  4/24/2016   4:48
# 1               0         36499.0     @BitcoinMoney  4/24/2016   4:52
# 2               0         36499.0     @BitcoinMoney  4/24/2016   4:57
# 3               1         18633.0    @cryptonewsday  4/24/2016   5:30
# 4               0         18633.0    @cryptonewsday  4/24/2016   9:30
# 5               0         18633.0    @cryptonewsday  4/24/2016  10:30
# 6               0         18633.0    @cryptonewsday  4/24/2016  11:30
# 7               0         18633.0    @cryptonewsday  4/24/2016  13:30
# 8               0         36499.0     @BitcoinMoney  4/24/2016  15:04
# 9               1         18633.0    @cryptonewsday  4/24/2016  15:30
# 10              1        736517.0       @blockchain  4/24/2016  15:40
# 11              2        736517.0       @blockchain  4/24/2016  15:41
# 12              1        736517.0       @blockchain  4/24/2016  15:42
# 13              2        736517.0       @blockchain  4/24/2016  15:42
# 14             23        736517.0       @blockchain  4/24/2016  15:45
# 15              0         18633.0    @cryptonewsday  4/24/2016  17:00
# 16             20        736517.0       @blockchain  4/24/2016  18:42
# 17              1        736517.0       @blockchain  4/24/2016  18:47
# 18            127        570797.0        @rogerkver  4/24/2016  22:55
# 19              1         18633.0    @cryptonewsday  4/25/2016   1:00
# 20              0        570797.0        @rogerkver  4/25/2016   1:19
# 21              0         36499.0     @BitcoinMoney  4/25/2016   2:52
# 22              0         36499.0     @BitcoinMoney  4/25/2016   2:55
# 23              0         36499.0     @BitcoinMoney  4/25/2016   2:58
# 24              0         18633.0    @cryptonewsday  4/25/2016   4:00
# 25              0         18633.0    @cryptonewsday  4/25/2016   6:00
# 26              0         18633.0    @cryptonewsday  4/25/2016   7:00
# 27              0         18633.0    @cryptonewsday  4/25/2016   8:00
# 28              0         18633.0    @cryptonewsday  4/25/2016   8:00
# 29              3         28206.0      @BitcoinByte  4/25/2016   8:13
# ..            ...             ...               ...        ...    ...
# 70              0        736517.0       @blockchain  4/25/2016  23:08
# 71              0         18633.0    @cryptonewsday  4/26/2016   1:00
# 72              0         36499.0     @BitcoinMoney  4/26/2016   1:23
# 73              1         18633.0    @cryptonewsday  4/26/2016   3:00
# 74              0         36499.0     @BitcoinMoney  4/26/2016   4:30
# 75              0         18633.0    @cryptonewsday  4/26/2016   6:00
# 76              1         18633.0    @cryptonewsday  4/26/2016   8:00
# 77              1         18633.0    @cryptonewsday  4/26/2016   9:00
# 78              1         18633.0    @cryptonewsday  4/26/2016  11:00
# 79              1         18633.0    @cryptonewsday  4/26/2016  13:00
# 80              2         36499.0     @BitcoinMoney  4/26/2016  14:08
# 81              9        549191.0  @BitcoinMagazine  4/26/2016  14:21
# 82              6        549191.0  @BitcoinMagazine  4/26/2016  15:48
# 83              1         18633.0    @cryptonewsday  4/26/2016  17:00
# 84              0        736517.0       @blockchain  4/26/2016  17:42
# 85              7        736517.0       @blockchain  4/26/2016  18:05
# 86             26        549191.0  @BitcoinMagazine  4/26/2016  18:07
# 87              0        736517.0       @blockchain  4/26/2016  18:26
# 88              0        736517.0       @blockchain  4/26/2016  18:35
# 89              0         18633.0    @cryptonewsday  4/26/2016  19:00
# 90              0         18633.0    @cryptonewsday  4/26/2016  21:00
# 91              3        736517.0       @blockchain  4/26/2016  21:24
# 92              0         18633.0    @cryptonewsday  4/26/2016  22:00
# 93              0         36499.0     @BitcoinMoney  4/26/2016  22:01
# 94              0         36499.0     @BitcoinMoney  4/26/2016  22:12
# 95              0         36499.0     @BitcoinMoney  4/26/2016  22:13
# 96              0         36499.0     @BitcoinMoney  4/26/2016  22:16
# 97              0         18633.0    @cryptonewsday  4/26/2016  23:00
# 98             48        113653.0          @JihanWu  4/27/2016   0:17
# 99              0         18633.0    @cryptonewsday  4/27/2016   1:00
#
# [100 rows x 9 columns]

# %%
re_tok = re.compile(f'([{string.punctuation}“”¨«»®´·º½¾¿¡§£₤‘’])')

def tokenize(s):
    return re_tok.sub(r' \1 ', s).split()

# %%
tweets['text'] = tweets['text'].apply(tokenize)
tweets['text'] = tweets['text'].apply(lambda x: [item for item in x if item not in stop])

# %%
tweets.head()
# Out:
#       tweet_id    created_date  \
# 0  7.24098E+17  4/24/2016 4:48
# 1  7.24099E+17  4/24/2016 4:52
# 2    7.241E+17  4/24/2016 4:57
# 3  7.24108E+17  4/24/2016 5:30
# 4  7.24169E+17  4/24/2016 9:30
#
#                                                 text  retweet_count  \
# 0  [hugo, chavez, daughter, assets, andorran, ban...          111.0
# 1  [taxpayer, major, counterparty, wall, street, ...           91.0
# 2                [ethereum, founder, sold, position]           54.0
# 3            [site, best, #, bitcoin, casino, games]            0.0
# 4                                [#, bitcoin, loans]            0.0
#
#   favorite_count  follower_count         account       date  time
# 0              0         36499.0   @BitcoinMoney  4/24/2016  4:48
# 1              0         36499.0   @BitcoinMoney  4/24/2016  4:52
# 2              0         36499.0   @BitcoinMoney  4/24/2016  4:57
# 3              1         18633.0  @cryptonewsday  4/24/2016  5:30
# 4              0         18633.0  @cryptonewsday  4/24/2016  9:30
